# %% [markdown]
# <a href="https://colab.research.google.com/github/PradeepChigadani/Pradeep/blob/main/CIE_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
import xgboost as xgb
from sklearn.linear_model import LinearRegression
df=pd.read_csv('/content/train_with_target.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
target=df['target']

# %%
train=df.drop('target',axis=1)

# %%
x_train,x_test,y_train,y_test=train_test_split(train,target,test_size=0.20)

# %%
x_train
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 347          348         1       3  Davison, Mrs. Thomas Henry (Mary E Finck)
# 60            61         0       3                      Sirayanian, Mr. Orsen
# 778          779         0       3                    Kilgannon, Mr. Thomas J
# 466          467         0       2                      Campbell, Mr. William
# 864          865         0       2                     Gill, Mr. John William
# ..           ...       ...     ...                                        ...
# 282          283         0       3                  de Pelsmaeker, Mr. Alfons
# 813          814         0       3         Andersson, Miss. Ebba Iris Alfrida
# 878          879         0       3                         Laleff, Mr. Kristo
# 30            31         0       1                   Uruchurtu, Don. Manuel E
# 390          391         1       1                 Carter, Mr. William Ernest
#
# ...

# %%
x_test
# Out:
#      PassengerId  Survived  Pclass  \
# 301          302         1       3
# 523          524         1       1
# 713          714         0       3
# 458          459         1       2
# 868          869         0       3
# ..           ...       ...     ...
# 565          566         0       3
# 866          867         1       2
# 351          352         0       1
# 845          846         0       3
# 751          752         1       3
#
#                                                 Name     Sex   Age  SibSp  \
# 301                               McCoy, Mr. Bernard    male   NaN      2
# 523  Hippach, Mrs. Louis Albert (Ida Sophia Fischer)  female  44.0      0
# 713                       Larsson, Mr. August Viktor    male  29.0      0
# 458                              Toomey, Miss. Ellen  female  50.0      0
# 868                      van Melkebeke, Mr. Philemon    male   NaN      0
# ..                                               ...     ...   ...    ...
# ...

# %%
y_train
# Out:
# 347    1
# 60     0
# 778    0
# 466    0
# 864    0
#       ..
# 282    0
# 813    0
# 878    0
# 30     0
# 390    1
# Name: target, Length: 712, dtype: int64

# %%
y_test
# Out:
# 301    1
# 523    1
# 713    0
# 458    1
# 868    0
#       ..
# 565    0
# 866    1
# 351    0
# 845    0
# 751    1
# Name: target, Length: 179, dtype: int64

# %%
model_1=LinearRegression()
model_2=xgb.XGBRegressor()
model_3=RandomForestRegressor()

# %%
model_1.fit(x_train, y_target)
model_2.fit(x_train, y_target)
model_3.fit(x_train, y_target)
# Out:
# RandomForestRegressor()

# %%
pred_1=model_1.predict(x_test)
pred_2=model_2.predict(x_test)
pred_3=model_3.predict(x_test)

# %%
pred_final=(pred_1+pred_2+pred_3)/3.0

# %%
print(mean_squared_error(y_test,pred_final))
# Out:
# 1.2477819938369487e-10
